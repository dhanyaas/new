# %%
import numpy as np
lt=[]
n=int(input("Enter number of elemets:"))
for i in range(0,n):
    ele=int(input())
    lt.append(ele)
print(lt)
arr=np.array(lt)
arr=np.sort(arr)
print("Sorted Array={}".format(arr))

ele=int(input("Enter element to search:"))
i=np.where(arr==ele)
print("index={}".format(i))
s=int(input("Enter splitting value:"))
newarr=np.array_split(arr,s)
print(newarr)
# Out:
# Enter number of elemts:4
# 4
# 5
# 7
# 8
# [4, 5, 7, 8]
# Sorted Array=[4 5 7 8]
# Enter element to search:6
# index=(array([], dtype=int64),)
# Enter splitting value:7
# [array([4]), array([5]), array([7]), array([8]), array([], dtype=int64), array([], dtype=int64), array([], dtype=int64)]

# %%
import numpy as np
from numpy import array,argmin,sqrt,sum
observation=array([111.0,188.0])
codes=array([[102.0,203.0],
             [132.0,193.0],
            [45.0,155.0],
            [57.0,173.0]])
diff=codes-observation
dist=sqrt(sum(diff**2,axis=-1))
print(observation,observation.shape)
print(codes,codes.shape)

print(diff,diff.shape)
print(dist,dist.shape)
argmin(dist)
# Out:
# [111. 188.] (2,)
# [[102. 203.]
#  [132. 193.]
#  [ 45. 155.]
#  [ 57. 173.]] (4, 2)
# [[ -9.  15.]
#  [ 21.   5.]
#  [-66. -33.]
#  [-54. -15.]] (4, 2)
# [17.49285568 21.58703314 73.79024326 56.04462508] (4,)
# 0

# %%
import numpy as np
import matplotlib.pyplot as plt

x=np.arange(0,3 * np.pi,0.1)
y_sin=np.sin(x)
y_cos=np.cos(x)
plt.plot(x,y_sin)
plt.plot(x,y_cos)
plt.xlabel('x axis label')
plt.ylabel('y axis label')
plt.title('sine and cosine')
plt.legend(['sine','cosine'])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([2,4,6,8])
y=x*2
plt.plot(x,y)
plt.show()

# %%
import pandas as pd 
import numpy as np
df=pd.DataFrame(np.random.rand(20,5),columns=['A','B','C','D','E'])
df.plot.box(grid="True")

from matplotlib import pyplot as plt

x=[74,88,52,72,78]
y=[23,22,54,69,80]
plt.show()

# %%
from matplotlib import pyplot as plt
y=[1,15,19,40,65]
plt.hist(y)
plt.show()

# %%
from pandas import DataFrame
import matplotlib.pylot as plt
data=[{8,9,3,4},{4,6,9,1},{7,4,1,3},{9,5,1,3},{7,1,3,9}]
Index=['I1','I2','I3','I4','I5']
cols=['c1','c2','c3','c4']
df=DaraFrame(data,Index,columns=cols)
plt.pcolor(df)
plt.show
